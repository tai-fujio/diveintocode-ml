# %% [markdown]
# # 【課題1】練習のために特徴量とカテゴリを選択
# * irisデータセットをWeek3同様に取得した後、データフレームから下記を抜き出す
#     - virgicolorとvirginica(1・2)

# %%
from sklearn.datasets import load_iris
import pandas as pd

# irisデータセットをロード
iris = load_iris()

# 説明変数をdf型に変換し、カラムをセット
df = pd.DataFrame(
    iris.data, 
    columns = iris.feature_names
)

# 目的変数をspeciesカラムに格納
df['species'] = iris.target

# virgicolorとvirginicaを抜き出す
df = df[df['species'].isin([1, 2])]

df
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 50                 7.0               3.2                4.7               1.4
# 51                 6.4               3.2                4.5               1.5
# 52                 6.9               3.1                4.9               1.5
# 53                 5.5               2.3                4.0               1.3
# 54                 6.5               2.8                4.6               1.5
# 55                 5.7               2.8                4.5               1.3
# 56                 6.3               3.3                4.7               1.6
# 57                 4.9               2.4                3.3               1.0
# 58                 6.6               2.9                4.6               1.3
# 59                 5.2               2.7                3.9               1.4
# 60                 5.0               2.0                3.5               1.0
# ...

# %% [markdown]
#    * sepal_lengthとpetal_length

# %%
# sepal_lengthとpetal_lengthを抜き出す
df = df.iloc[:, [0, 2, 4]]

df
# Out:
#      sepal length (cm)  petal length (cm)  species
# 50                 7.0                4.7        1
# 51                 6.4                4.5        1
# 52                 6.9                4.9        1
# 53                 5.5                4.0        1
# 54                 6.5                4.6        1
# 55                 5.7                4.5        1
# 56                 6.3                4.7        1
# 57                 4.9                3.3        1
# 58                 6.6                4.6        1
# 59                 5.2                3.9        1
# 60                 5.0                3.5        1
# 61                 5.9                4.2        1
# 62                 6.0                4.0        1
# 63                 6.1                4.7        1
# 64                 5.6                3.6        1
# 65                 6.7                4.4        1
# 66                 5.6                4.5        1
# ...

# %% [markdown]
# # 【問題2】データの分析
# * sepal_lengthとpetal_lengthを使い、散布図・箱ひげ図・バイオリン図を作成
#
#
#
# * 散布図

# %%
import matplotlib.pyplot as plt

plt.scatter(
    x = 'sepal length (cm)',
    y = 'petal length (cm)',
    data = df[df['species'] ==  1],
    c = 'r',
    marker = '*'
)

plt.scatter(
    x = 'sepal length (cm)',
    y = 'petal length (cm)',
    data = df[df['species'] ==  2],
    c = 'g',
    marker = '*'
)

# 星かわいい

# %% [markdown]
# * 箱ひげ図

# %%
import seaborn as sns

sns.boxplot(x = 'species', y = 'sepal length (cm)' , data = df)

# %%
sns.boxplot(x = 'species', y = 'petal length (cm)' , data = df)

# %% [markdown]
# * バイオリン図

# %%
sns.violinplot(x = 'species', y = 'sepal length (cm)' , data = df)

# %%
sns.violinplot(x = 'species', y = 'petal length (cm)' , data = df)

# %% [markdown]
# # 【問題2】前処理・学習用データと検証用データの分割
# * 前処理で学習用データ(75%)と検証用データ(25%)への分割を行う
# * scikit-learnのtrain_test_splitを利用
# * 特徴量（説明変数）をX、正解（目的変数）をyというndarrayに格納

# %%
from sklearn.model_selection import train_test_split

# 説明変数・目的変数をX・yに格納
X = df.iloc[:, [0, 1]].values
y = df.iloc[:, [2]].values

# 分割
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size = 0.25,
    random_state = 15
)

print('X_train：')
print(X_train)
print('X_test：')
print(X_test)
print('y_train：')
print(y_train)
print('y_test：')
print(y_test)
# Out:
# X_train：
# [[7.9 6.4]
#  [6.3 5. ]
#  [5.5 3.8]
#  [6.1 4.7]
#  [5.6 4.5]
#  [6.9 5.7]
#  [6.  5. ]
#  [6.2 4.5]
#  [6.7 5.8]
#  [5.  3.3]
#  [6.4 5.5]
#  [6.9 5.4]
#  [5.8 5.1]
#  [6.5 5.5]
#  [6.  5.1]
#  [7.1 5.9]
#  [5.1 3. ]
#  [6.2 5.4]
#  [5.8 5.1]
#  [6.2 4.8]
#  [7.2 5.8]
#  [5.7 4.2]
#  [7.7 6.7]
#  [6.4 4.3]
#  [6.5 5.8]
#  [7.4 6.1]
#  [6.3 5.6]
#  [5.8 4. ]
#  [6.9 4.9]
#  [4.9 3.3]
#  [6.5 4.6]
#  [6.  4.5]
#  [6.7 5.2]
#  [6.3 4.9]
#  [6.7 5.7]
#  [6.9 5.1]
#  [6.3 4.9]
#  [5.5 4.4]
#  [6.4 5.6]
#  [6.1 4.6]
#  [6.3 5.6]
#  [6.4 5.3]
#  [6.3 6. ]
#  [5.4 4.5]
#  [6.8 4.8]
#  [6.  4.8]
#  [6.4 4.5]
#  [5.7 4.1]
#  [4.9 4.5]
#  [6.3 5.1]
#  [5.7 3.5]
#  [6.5 5.1]
#  [6.1 4.9]
#  [5.6 4.2]
#  [5.6 3.9]
#  [6.3 4.4]
#  [5.5 4. ]
#  [7.7 6.9]
#  [6.7 4.4]
#  [5.  3.5]
#  [6.8 5.5]
#  [5.8 3.9]
#  [6.1 4.7]
#  [5.5 3.7]
#  [5.8 4.1]
#  [6.2 4.3]
#  [7.7 6.1]
#  [7.2 6. ]
#  [5.6 4.9]
#  [6.7 5. ]
#  [6.  4.5]
#  [7.  4.7]
#  [5.7 4.5]
#  [6.  4. ]
#  [7.7 6.7]]
# X_test：
# ...

# %% [markdown]
# # 【問題3】前処理・標準化
# * 標準化を行う
# * scikit-learnのStandardScalerを利用
# * 標準化は学習用データでfitを行い、学習用、検証用双方のデータにtransformを行う

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

# 学習用データの最大値、最小値、平均、標準偏差、傾き...などの統計を取得
scaler.fit(X_train)

# 統計に基づき各データを書き換え
X_train = scaler.transform(X_train)
X_test = scaler.transform(X_test)

print('X_train：')
print(X_train)
print('X_test：')
print(X_test)
# Out:
# X_train：
# [[ 2.41366053  1.83195138]
#  [ 0.06078268  0.1401757 ]
#  [-1.11565625 -1.30991774]
#  [-0.23332705 -0.22234766]
#  [-0.96860138 -0.4640299 ]
#  [ 0.94311187  0.98606354]
#  [-0.38038192  0.1401757 ]
#  [-0.08627219 -0.4640299 ]
#  [ 0.64900214  1.10690466]
#  [-1.85093058 -1.91412334]
#  [ 0.20783754  0.7443813 ]
#  [ 0.94311187  0.62354018]
#  [-0.67449165  0.26101682]
#  [ 0.35489241  0.7443813 ]
#  [-0.38038192  0.26101682]
#  [ 1.23722161  1.22774578]
#  [-1.70387571 -2.2766467 ]
#  [-0.08627219  0.62354018]
#  [-0.67449165  0.26101682]
#  [-0.08627219 -0.10150654]
#  [ 1.38427647  1.10690466]
#  [-0.82154652 -0.82655326]
#  [ 2.1195508   2.19447474]
#  [ 0.20783754 -0.70571214]
#  [ 0.35489241  1.10690466]
#  [ 1.6783862   1.46942802]
#  [ 0.06078268  0.86522242]
#  [-0.67449165 -1.0682355 ]
#  [ 0.94311187  0.01933458]
#  [-1.99798545 -1.91412334]
#  [ 0.35489241 -0.34318878]
#  [-0.38038192 -0.4640299 ]
#  [ 0.64900214  0.38185794]
#  [ 0.06078268  0.01933458]
# ...

# %% [markdown]
# # 【問題4】学習と推定
# * 最近傍法で学習を行う
# * scikit-learnのKNeighborsClassifierを利用
# * 学習・検証用データをpredictメソッドに入力し推定
# * n_neighborsの数にデフォルトの5、および1と3を指定

# %%
from sklearn.neighbors import KNeighborsClassifier
import numpy as np

# 予測結果格納用
y_pred_ary = np.zeros((0, 25))

# n_neighborsに指定する数
n_neighbors = [1, 3, 5]

for n in n_neighbors:
    neigh = KNeighborsClassifier(n)
   
    # 学習用データから学習
    neigh.fit(X_train, y_train.reshape(-1)) # エラーが出るためreshape
    
    #  予測を実施・格納
    y_pred_ary = np.append(y_pred_ary, [neigh.predict(X_test)], axis = 0)
    
    
print(y_pred_ary)
# Out:
# [[2. 1. 2. 2. 1. 2. 2. 1. 1. 2. 2. 1. 1. 2. 1. 1. 2. 1. 2. 2. 1. 1. 2. 2.
#   2.]
#  [2. 1. 2. 2. 1. 2. 2. 1. 1. 2. 2. 1. 1. 2. 1. 1. 2. 1. 2. 2. 2. 1. 2. 2.
#   2.]
#  [2. 1. 2. 2. 1. 2. 2. 1. 1. 2. 2. 1. 1. 2. 1. 1. 2. 1. 2. 2. 2. 1. 2. 2.
#   1.]]

# %% [markdown]
# # 【問題5】評価
# * scikit-learnのmetricsを使って、評価指標の計算を行う
# * 指標は下記の通り
#
#     TP: True Positive
#     正しく陽性と判定できた場合
#
#     TP: True Negative
#     正しく陰性と判定できた場合
#
#     FP: False Positive
#     本来は陰性なところを、誤って陽性と判定してしまった場合
#
#     FN: False Negative
#     本来は陽性なところを、誤って陰性と判定してしまった場合
#
# <br><br>
#
#  * accuracyを求める 計算式は下記の通り
#
#     $Accuracy = \frac{TP + TN}{TP + FP + FN + TN}$

# %%
from sklearn import metrics

for y_pred in y_pred_ary:
    print('accuracy : {}'.format(metrics.accuracy_score(y_test, y_pred)))
# Out:
# accuracy : 0.88
# accuracy : 0.92
# accuracy : 0.96

# %% [markdown]
#  * precisionを求める 計算式は下記の通り
#
#     $precision = \frac{TP}{TP + FP}$

# %%
for y_pred in y_pred_ary:
    print('precision : {}'.format(metrics.precision_score(y_test, y_pred)))
# Out:
# precision : 0.9090909090909091
# precision : 1.0
# precision : 1.0

# %% [markdown]
#  * recallを求める 計算式は下記の通り
#
#     $recall = \frac{TP}{TP + FN}$

# %%
for y_pred in y_pred_ary:
    print('recall : {}'.format(metrics.recall_score(y_test, y_pred)))
# Out:
# recall : 0.8333333333333334
# recall : 0.8333333333333334
# recall : 0.9166666666666666

# %% [markdown]
# * f値を求める 計算式は下記の通り
#     $F-measure = 2 \frac{Precision \cdot Recall}{Precision + Recall}$

# %%
for y_pred in y_pred_ary:
    print('f値 : {}'.format(metrics.f1_score(y_test, y_pred)))
# Out:
# f値 : 0.8695652173913043
# f値 : 0.9090909090909091
# f値 : 0.9565217391304348

# %% [markdown]
# * 混同行列
# 下記の通りに出力される
#
#
# |#  |Positive  |Negative  |
# |Positive  |TP  |FN  |
# |Negative  |FP  |TN  |

# %%
for y_pred in y_pred_ary:
    print(metrics.confusion_matrix(y_test, y_pred))
# Out:
# [[10  2]
#  [ 1 12]]
# [[10  2]
#  [ 0 13]]
# [[11  1]
#  [ 0 13]]

# %% [markdown]
# # 【問題6】可視化

# %%
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap
import matplotlib.patches as mpatches

def decision_region(X_train, y_train, model, step=0.01, title='decision region', xlabel='xlabel', ylabel='ylabel', target_names=['versicolor', 'virginica']):
    """
    2値分類を2次元の特徴量で学習したモデルの決定領域を描く。
    背景の色が学習したモデルによる推定値から描画される。
    散布図の点は学習用データである。

    Parameters
    ----------------
    X_train : ndarray, shape(n_samples, 2)
        学習用データの特徴量
    y_train : ndarray, shape(n_samples,)
        学習用データの正解値
    model : object
        学習したモデルのインスンタスを入れる
    step : float, (default : 0.1)
        推定値を計算する間隔を設定する
    title : str
        グラフのタイトルの文章を与える
    xlabel, ylabel : str
        軸ラベルの文章を与える
    target_names= : list of str
        凡例の一覧を与える
    """
    # setting
    scatter_color = ['red', 'blue']
    contourf_color = ['pink', 'skyblue']
    n_class = 2

    # pred
    mesh_f0, mesh_f1  = np.meshgrid(np.arange(np.min(X_train[:,0])-0.5, np.max(X_train[:,0])+0.5, step), np.arange(np.min(X_train[:,1])-0.5, np.max(X_train[:,1])+0.5, step))
    mesh = np.c_[np.ravel(mesh_f0),np.ravel(mesh_f1)]
    pred = model.predict(mesh).reshape(mesh_f0.shape)

    # plot
    plt.title(title)
    plt.xlabel(xlabel)
    plt.ylabel(ylabel)
    plt.contourf(mesh_f0, mesh_f1, pred, n_class-1, cmap=ListedColormap(contourf_color))
    plt.contour(mesh_f0, mesh_f1, pred, n_class-1, colors='y', linewidths=3, alpha=0.5)
    for i, target in enumerate(set(y_train)):
        plt.scatter(X_train[y_train==target][:, 0], X_train[y_train==target][:, 1], s=80, color=scatter_color[i], label=target_names[i], marker='o')
    patches = [mpatches.Patch(color=scatter_color[i], label=target_names[i]) for i in range(n_class)]
    plt.legend(handles=patches)
    plt.legend()
    plt.show()
    
    
# 3-nnでインスタンス化
neigh = KNeighborsClassifier(3)
   
# 学習用データから学習
neigh.fit(X_train, y_train.reshape(-1))   # エラーが出るためreshape
    
# プロット関数をコール
decision_region(
    X_train=X_train, 
    y_train=y_train.reshape(-1),                # エラーが出るためreshape
    model=neigh,
    title='decision region of 3-nn', 
    xlabel='sepal length', 
    ylabel='petal length'
)

# %% [markdown]
# # 【問題7】他の手法の学習
# 以下の全ての手法について学習・推定・評価・可視化を行う(デフォルトで実施)
# * (最近傍法)問題4~6で実施済
# * ロジスティック回帰
# * SVM
# * 決定木
# * ランダムフォレスト

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier

# 各手法インスタンス格納用
clf_dict = {}

# 各手法インスタンス作成
# ロジスティック回帰
lg_clf = LogisticRegression(random_state=0, solver='lbfgs',multi_class='multinomial')
clf_dict['LogisticRegression'] = lg_clf

# SVM
svc_clf = SVC(gamma='auto')
clf_dict['SVM'] = svc_clf

# 決定木
dt_clf = DecisionTreeClassifier(random_state=0)
clf_dict['DecisionTree'] = dt_clf

# ランダムフォレスト 
rf_clf = RandomForestClassifier(n_estimators=100, max_depth=2,random_state=0)
clf_dict['RandomForest'] = rf_clf


for clf_key in clf_dict:
    # 学習
    clf_dict[clf_key].fit(X_train, y_train.reshape(-1)) 
    
    # 予測実施
    y_pred = clf_dict[clf_key].predict(X_test)
    
    print('{} : '.format(clf_key))
    
    # 各評価
    print('accuracy : {}'.format(metrics.accuracy_score(y_test, y_pred)))
    print('precision : {}'.format(metrics.precision_score(y_test, y_pred)))
    print('recall : {}'.format(metrics.recall_score(y_test, y_pred)))
    print('f値 : {}'.format(metrics.f1_score(y_test, y_pred)))
    print(metrics.confusion_matrix(y_test, y_pred))
    
    # 可視化
    # プロット関数をコール
    decision_region(
        X_train=X_train, 
        y_train=y_train.reshape(-1),                # エラーが出るためreshape
        model=clf_dict[clf_key],
        title='decision region of {}'.format(clf_key),
        xlabel='sepal length', 
        ylabel='petal length'
    )
# Out:
# LogisticRegression :
# accuracy : 0.96
# precision : 1.0
# recall : 0.9166666666666666
# f値 : 0.9565217391304348
# [[11  1]
#  [ 0 13]]
# SVM :
# accuracy : 0.96
# precision : 1.0
# recall : 0.9166666666666666
# f値 : 0.9565217391304348
# [[11  1]
#  [ 0 13]]
# DecisionTree :
# accuracy : 0.92
# precision : 0.9166666666666666
# recall : 0.9166666666666666
# f値 : 0.9166666666666666
# [[11  1]
#  [ 1 12]]
# RandomForest :
# accuracy : 0.96
# precision : 1.0
# recall : 0.9166666666666666
# f値 : 0.9565217391304348
# [[11  1]
#  [ 0 13]]

# %% [markdown]
# * どの手法がどの指標値が良かったか・どういった決定領域になっていたか
#
#     * ロジスティック回帰<br>
#         どの指標値がよかったか ： 全て<br>
#         どういった決定領域 : 直線になっている<br>
# <br>
#     * SVM<br>
#         どの指標値がよかったか ： 全て<br>
#         どういった決定領域 : 曲線になっている<br>
# <br>
#     * 決定木<br>
#         どの指標値がよかったか ： recallのみ<br>
#         どういった決定領域 : 段になっている<br>
# <br>
#     * ランダムフォレスト<br>
#         どの指標値がよかったか ： 全て<br>
#         どういった決定領域 : 細かな段になっている<br>
